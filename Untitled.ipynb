# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy 
# %matplotlib inline


plt.(x,y)
plt.show()

# %%
alpha = 2/(14-1)
series = pd.Series([alpha * (1-alpha)**i for i in range(14)])
plt.bar(left=range(14), height=series)
plt.show()

# %%
1527*0.0175
# Out:
# 26.722500000000004
